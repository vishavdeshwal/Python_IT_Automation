# %%
def to_seconds(hours, minutes, seconds):
    return hours*3600+minutes*60+seconds

print("Welcome to this time converter")

count = "y"
while(count.lower() == "y"):
    hours = int(input("Enter the number of hours: "))
    minutes = int(input("Enter the number of minutes: "))
    seconds = int(input("Enter the number of seconds: "))

    print("That's {} seconds".format(to_seconds(hours, minutes, seconds)))
    print()
    count = input("Do you want to do another conversion? [y to continue] ")
    
print("Goodbye!")
# Out:
# Welcome to this time converter
# That's 25005 seconds
#
# Goodbye!

# %%
#!/usr/bin/env python3

import os
import sys

fileName=input(sys.argv[1])

if not os.path.exists(fileName):
     with open(fileName, "w") as f:
       f.write("New File created\n")
else: 
   print("Error, the file {} already exists ".format(fileName))
   sys.exit(1)
# Out:
# Error, the file blabla already exists
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /Users/vishv/Library/Python/3.12/lib/python/site-packages/IPython/core/interactiveshell.py:3678: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
