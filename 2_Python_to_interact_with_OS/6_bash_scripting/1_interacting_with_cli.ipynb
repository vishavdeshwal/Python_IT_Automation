# %% [markdown]
# Linux Basic Commands
#
# echo
# cat
# ls
# chmod
#
# .. = previous or parent directory to your current directory.
#
# # > = It is used to redirect the output of anything into another file that we choose to place.
#
# # >> This is to append the output in a new file
# # cat example.txt >> new_file.txt
#
# # < It is used to read the file
# # ./streams_err.py < new_file.txt
# # To capture error we use  = 2>
# # ./streams_err.py 2> err.txt

# %% [markdown]
# Signaling Processes -> Tokens delivered to running processes to indicate a desired action  (cntrl + c)
