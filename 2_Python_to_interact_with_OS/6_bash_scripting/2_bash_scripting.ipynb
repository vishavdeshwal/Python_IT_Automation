# %% [markdown]
# globs = * or ?
# echo *.py = all files that ends with .py
# echo $? = print the last command executed successfully or not
# echo c* = all files starts with letter c
# echo * = all files in the current dir
